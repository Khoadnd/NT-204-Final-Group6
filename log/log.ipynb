# %%
import pandas as pd

# %%
RF_log = pd.read_feather("RF_attackgan_log.feather")

# %%
RF_log
# Out:
#         step  epoch   loss_critic  loss_gen  loss_blackbox
# 0        0.0    0.0 -9.094947e-11  1.342249       2.684538
# 1        1.0    0.0 -4.383764e-10  1.333610       2.667259
# 2        2.0    0.0 -1.340595e-09  1.370464       2.740968
# 3        3.0    0.0 -1.567241e-08  1.276632       2.553303
# 4        4.0    0.0 -2.073648e-10  1.446573       2.893185
# ...      ...    ...           ...       ...            ...
# 10075  283.0   34.0  1.818989e-12  1.312576       2.625191
# 10076  284.0   34.0 -1.818989e-12  1.303370       2.606779
# 10077  285.0   34.0 -1.818989e-12  1.408985       2.818008
# 10078  286.0   34.0 -1.818989e-12  1.393405       2.786849
# 10079  287.0   34.0  1.818989e-12  1.438599       2.877235
#
# [10080 rows x 5 columns]
